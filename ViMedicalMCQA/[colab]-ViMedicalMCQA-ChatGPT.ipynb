# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Project/MCQA/ViMedicalMCQA
# Out:
# /content/drive/MyDrive/Project/MCQA/ViMedicalMCQA

# %%
import pandas as pd

df = pd.read_csv('./data/public_test_with_context_en.csv')

# %%
df
# Out:
#            id                                           question  \
# 0    level3_1  Huong is pregnant and worried she may have pla...
# 1    level3_2  Huong is 5 weeks pregnant and is worried she m...
# 2    level3_5  How many strikers know that in football, each ...
# 3   level3_13  Patient Dung was diagnosed with hepatitis last...
# 4   level3_14  A patient has testicular pain. After being que...
# ..        ...                                                ...
# 95   level4_4  Xiao Tang is a famous female singer in China. ...
# 96   level4_9  Mai is currently 9 months pregnant. There are ...
# 97  level4_27  Mr. Bien is 73 years old this year. During a f...
# 98  level4_28  Brain tumor is a condition in which tumors for...
# 99  level4_35  Vaccines are antigenic preparations originatin...
#
#                             option_1              option_2  \
# 0                         A. Week 10             B.Week 20
# 1                         A. 5 weeks           B. 15 weeks
# ...

# %%
row = df.iloc[0]

# %%
context = row["context"].split("///")[0]
question = row["question"]
choices = "\n".join(
    [
        op for op in row[["option_1", "option_2", "option_3", "option_4", "option_5", "option_6"]].tolist()
        if isinstance(op, str)
    ]
)
prompt = f"Context: {context}. Question: {question}. Choice the correct answers from: {choices}"

# %%
prompt
# Out:
# 'Context: Method of diagnosing placenta praevia Usually, the diagnosis is made by ultrasound. In addition, ultrasound is also important in diagnosing placenta previa, complications of placenta accreta. (4) Ultrasound images will show that the distance between the placenta and the bladder wall is narrowed, blood vessels passing through the uterine muscle wall to the bladder wall are common on Doppler ultrasound. Therefore, ultrasound is recommended to be performed after the 28th week of pregnancy to detect this complication early. . Question: Huong is pregnant and worried she may have placenta previa. Huong can be tested to detect this disease from what week of pregnancy?. Choice the correct answers from: A. Week 10\nB.Week 20\nC. Week 30\nD. Week 40'

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 73.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 38.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 105.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 88.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 37.5 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Project/MCQA/MedMCQA
# Out:
# /content/drive/MyDrive/Project/MCQA/MedMCQA

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = './model/checkpoint-6000'
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-small")
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# <ipython-input-13-5ed672e6ee61> in <cell line: 5>()
#       3 model_name = './model/checkpoint-6000'
#       4 tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-small")
# ----> 5 model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     485             if not isinstance(config, PretrainedConfig):
#     486                 # We make a call to the config file first (which may be absent) to get the commit hash as soon as possible
# --> 487                 resolved_config_file = cached_file(
#     488                     pretrained_model_name_or_path,
#     489                     CONFIG_NAME,
#
# ...

# %%
row
# Out:
# id                                                   level3_1
# question    Huong is pregnant and worried she may have pla...
# option_1                                           A. Week 10
# option_2                                            B.Week 20
# option_3                                           C. Week 30
# option_4                                           D. Week 40
# option_5                                                  NaN
# option_6                                                  NaN
# context     Method of diagnosing placenta praevia Usually,...
# Name: 0, dtype: object

# %%
choices = "\n".join(
    [
        op for op in row[["option_1", "option_2", "option_3", "option_4", "option_5", "option_6"]].tolist()
        if isinstance(op, str)
    ]
)

# %%
choices
# Out:
# 'A. Week 10\nB.Week 20\nC. Week 30\nD. Week 40'

# %%
context = row["context"].split("///")[0]
question = row["question"]

# %%
row["context"]
# Out:
# 'Method of diagnosing placenta praevia Usually, the diagnosis is made by ultrasound. In addition, ultrasound is also important in diagnosing placenta previa, complications of placenta accreta. (4) Ultrasound images will show that the distance between the placenta and the bladder wall is narrowed, blood vessels passing through the uterine muscle wall to the bladder wall are common on Doppler ultrasound. Therefore, ultrasound is recommended to be performed after the 28th week of pregnancy to detect this complication early. /// How many weeks will it take to know placenta praevia? Doctor Nguyen Duc Hinh said that most cases of placenta previa can be detected as early as the 20th week of pregnancy thanks to fetal ultrasound. During the ultrasound process, with the support of many modern equipment, the doctor can observe where in the uterus the placenta is attached (body, fundus, front, back, left, right). , low grip, semi-central or central). Diagnosis of placenta previa is mainly done b
# ...

# %%
prompt = f"{context}. {question}. Chọn các đáp án đúng trong các đáp án sau đây: {choices}"

# %%
prompt
# Out:
# 'Method of diagnosing placenta praevia Usually, the diagnosis is made by ultrasound. In addition, ultrasound is also important in diagnosing placenta previa, complications of placenta accreta. (4) Ultrasound images will show that the distance between the placenta and the bladder wall is narrowed, blood vessels passing through the uterine muscle wall to the bladder wall are common on Doppler ultrasound. Therefore, ultrasound is recommended to be performed after the 28th week of pregnancy to detect this complication early. . Huong is pregnant and worried she may have placenta previa. Huong can be tested to detect this disease from what week of pregnancy?. Chọn các đáp án đúng trong các đáp án sau đây: A. Week 10\nB.Week 20\nC. Week 30\nD. Week 40'

# %% [markdown]
# ##**Chat GPT**

# %%
# !pip install --upgrade --quiet openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.5 MB/s eta 0:00:00

# %%
import openai

OPENAI_API_KEY = "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"

# OPENAI API configuration
openai.api_key = OPENAI_API_KEY

# %%
def set_open_params(
    model="text-davinci-003",
    temperature=0.7,
    max_tokens=128,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0,
):
    """ set openai parameters"""

    openai_params = {}

    openai_params['model'] = model
    openai_params['temperature'] = temperature
    openai_params['max_tokens'] = max_tokens
    openai_params['top_p'] = top_p
    openai_params['frequency_penalty'] = frequency_penalty
    openai_params['presence_penalty'] = presence_penalty
    return openai_params

def get_completion(params, prompt):
    """ GET completion from openai api"""

    response = openai.Completion.create(
        engine = params['model'],
        prompt = prompt,
        temperature = params['temperature'],
        max_tokens = params['max_tokens'],
        top_p = params['top_p'],
        frequency_penalty = params['frequency_penalty'],
        presence_penalty = params['presence_penalty'],
    )
    return response.choices[0].text
params = set_open_params()

# %%
response = get_completion(params, prompt)
response
# Out:
# '\n\nC. Tuần 30'

# %%
system_msg = 'Choose the correct answers to the questions based on the context.'

def extract_answer(row):
    context = row["context"].split("///")[0]
    question = row["question"]
    choices = "\n".join(
        [
            op for op in row[["option_1", "option_2", "option_3", "option_4", "option_5", "option_6"]].tolist()
            if isinstance(op, str)
        ]
    )
    prompt = f"Context: {context}. Question {question}. Choose the correct answers from the following answers: {choices}"
    response = openai.ChatCompletion.create(model="gpt-3.5-turbo",
                                        messages=[{"role": "system", "content": system_msg},
                                         {"role": "user", "content": prompt}])
    response = response["choices"][0]["message"]["content"]
    # response = get_completion(params, prompt)
    return response

# %%
extract_answer(df.iloc[73])
# Out:
# 'Use condoms when having sex\nBe faithful to one husband and one wife'

# %%
df.iloc[5]["question"]
# Out:
# 'An has spondylitis, and Nam has diarrhea. Ask which group of diseases does Nam belong to?'

# %%
len(answers)
# Out:
# 74

# %%
import time

answers = []
for index, row in df.iterrows():
    print("")
    answer = extract_answer(row)
    print(f"{index} -- {answer}")
    answers.append(answer)
    time.sleep(20)
# Out:
# 0 -- C. Week 30
#
# 1 -- The correct answer is D. 35 weeks. Ultrasound is recommended to be performed after the 28th week of pregnancy to detect placenta previa.
#
# 2 -- None of the answers are correct because the given context does not mention anything about football or the number of strikers on the field.
#
# 3 -- The correct answer is: Have
#
# 4 -- C. Trauma
#
# 5 -- A. Digestive diseases
#
# 6 -- B. Imbalance of intestinal microflora
#
# 7 -- Have
#
# 8 -- C. Imaging diagnosis, functional exploration and nuclear medicine
#
# 9 -- Are not
#
# 10 -- A. Chest X-ray
#
# 11 -- B. No
#
# 12 -- C. Drink enough water every day, 1.5 - 2 liters
#
# 13 -- A. Urinating frequently during the day
#
# 14 -- A. An acute viral infection
#
# 15 -- The correct answers are A. Urinating frequently during the day and C. Urine mixed with pus or fresh blood.
#
# 16 -- C. During puberty and adulthood
#
# 17 -- A. Abnormal bleeding from the uterus, different from the normal menstrual cycle
#
# ...

# %%
answers[-1]
# Out:
# 'Use condoms when having sex\nBe faithful to one husband and one wife'

# %%
for index, row in df.iterrows():
    if index >=74:
        print("")
        answer = extract_answer(row)
        print(f"{index} -- {answer}")
        answers.extend(answer)
        time.sleep(20)
# Out:
# 74 -- None of the above diseases mentioned have an incubation period. The question is unrelated to the given context.
#
# 75 -- The correct answer is:
# - Blood tests
#
# 76 -- The correct answer is: Both diseases can develop from inflammation and damage to the lining of the stomach and duodenum.
#
# 77 -- Diop
#
# 78 -- Use eyeglasses
# Use contact lenses
# Surgery
#
# 79 -- The correct answer is: Both are skin diseases.
#
# 80 -- None of the listed symptoms (Whiteheads, Blackhead, Pustules, Cyst, Nodules) are associated with flat warts or hormonal warts. The correct answer is none of the above.
#
# 81 -- The correct answer is: Keep the skin area clean and limit direct contact with the sick person.
#
# 82 -- Women have a higher incidence of thyroid cancer.
#
# 83 -- - Keep your ears clean
# - Do not smoke and avoid exposure to secondhand smoke
#
# 84 -- Hepatitis A
#
# ...

# %% [markdown]
# Vi

# %%
system_msg = 'Chọn các đáp án đúng cho câu hỏi dựa vào ngữ cảnh sau đây và giải thích.'

def extract_answer_vi(row):
    context = row["context"].split("///")[0]
    question = row["question"]
    choices = "\n".join(
        [
            op for op in row[["option_1", "option_2", "option_3", "option_4", "option_5", "option_6"]].tolist()
            if isinstance(op, str)
        ]
    )
    prompt = f"Ngữ cảnh: {context}. Câu hỏi {question}. Chọn các đáp án đúng trong các đáp án sau đây: {choices}"
    response = openai.ChatCompletion.create(model="gpt-3.5-turbo-0613",
                                        messages=[{"role": "system", "content": system_msg},
                                         {"role": "user", "content": prompt}])
    response = response["choices"][0]["message"]["content"]
    # response = get_completion(params, prompt)
    return response

# %%
df = pd.read_csv('./data/public_test_with_context.csv')

# %%
df.iloc[0]
# Out:
# id                                                   level3_1
# question    Hương đang mang thai và lo lắng mình có thể gặ...
# option_1                                           A. Tuần 10
# option_2                                            B.Tuần 20
# option_3                                           C. Tuần 30
# option_4                                           D. Tuần 40
# option_5                                                  NaN
# option_6                                                  NaN
# context     Phương pháp chẩn đoán rau tiền đạo Thông thườn...
# Name: 0, dtype: object

# %%
extract_answer_vi(df.iloc[0])
# Out:
# 'Đáp án đúng: C. Tuần 30'

# %%
extract_answer_vi(df.iloc[1])
# Out:
# 'Ngữ cảnh cho biết rằng siêu âm được khuyến cáo thực hiện từ sau tuần thai thứ 28 để phát hiện sớm biến chứng rau cài răng lược. Vì vậy, Hương có thể kiểm tra phát hiện bệnh này sau 28 tuần thai, tức là sau tuần thứ 28. Do đó, câu trả lời đúng là C. 25 tuần.'

# %%
extract_answer_vi(df.iloc[6])
# Out:
# 'Đáp án đúng là B. Mất cân bằng hệ vi sinh đường ruột.\n\nViệc sử dụng thuốc kháng sinh một cách không đúng liều lượng hoặc không theo đơn có thể gây ra mất cân bằng trong hệ vi sinh đường ruột. Thuốc kháng sinh tác động không chỉ đến vi khuẩn gây bệnh mà còn ảnh hưởng đến vi khuẩn có ích trong đường ruột, gây ra mất cân bằng vi sinh và có thể dẫn đến các vấn đề về tiêu hóa.'

# %%
df.iloc[6]['question']
# Out:
# 'Việc sử dụng thuốc kháng sinh một cách tự tiện, quá liều lượng, không theo đơn có thể gây ra vấn đề nào?'

# %%
df.iloc[6]
# Out:
# id                                                  level3_22
# question    Việc sử dụng thuốc kháng sinh một cách tự tiện...
# option_1                     A. Tăng cường hấp thu dinh dưỡng
# option_2                 B.Mất cân bằng hệ vi sinh đường ruột
# option_3                                C. Giảm nhu động ruột
# option_4                          D. Không có đáp án nào đúng
# option_5                                                  NaN
# option_6                                                  NaN
# context     Triệu chứng tiểu không tự chủ Triệu chứng chủ ...
# Name: 6, dtype: object

# %%
import time

vi_answers = []
for index, row in df.iterrows():
    print("")
    answer = extract_answer_vi(row)
    print(f"{index} -- {answer}")
    vi_answers.append(answer)
    time.sleep(25)
# Out:
# 0 -- Đáp án đúng là C. Tuần 30.
# Theo đoạn văn, siêu âm được khuyến nghị thực hiện từ sau tuần thai thứ 28 để phát hiện sớm biến chứng rau cài răng lược. Vì vậy, Hương có thể kiểm tra phát hiện bệnh này từ tuần thứ 30 của thai kỳ.
#
# 1 -- Đáp án đúng là C. 25 tuần.
#
# Theo thông tin trong đoạn văn, siêu âm được khuyến cáo thực hiện từ sau tuần thai thứ 28 để phát hiện sớm biến chứng rau cài răng lược. Vì vậy, để kiểm tra phát hiện bệnh rau tiền đạo, Hương cần phải chờ đến tuần thứ 28 trở đi, tức là sau 25 tuần.
#
# 2 -- Ngữ cảnh cho biết việc chẩn đoán rau tiền đạo biến chứng rau cài răng lược được thực hiện bằng phương pháp siêu âm. Điều này không liên quan đến bóng đá hay các đội bóng có bao nhiêu tiền đạo trên sân. Do đó, không có thông tin trong ngữ cảnh để trả lời câu hỏi.
#
# 3 -- Không.
#
# ...

# %%
len(vi_answers)
# Out:
# 47

# %%
for index, row in df.iterrows():
    if index >= 47:
        print("")
        answer = extract_answer_vi(row)
        print(f"{index} -- {answer}")
        vi_answers.extend(answer)
        time.sleep(25)
# Out:
# 47 -- A. Đúng
#
# 48 -- Đáp án đúng là A. 1 loại. Bệnh cúm chỉ gây ra bởi vi rút cúm duy nhất (Influenza virus) chứ không phải là nhiều loại vi rút khác nhau.
#
# 49 -- Đáp án đúng là B. Oseltamivir, Zanamivir, Peramivir.
#
# Ngữ cảnh cho thấy chúng ta đang nói về vi rút cúm và cách điều trị cúm. Các loại thuốc kháng vi rút như Oseltamivir, Zanamivir và Peramivir là những thuốc được khuyên dùng trong điều trị cúm. Các loại thuốc kháng sinh như Amoxicillin, Ceftriaxone và Azithromycin không có tác dụng chống lại vi rút và không được sử dụng để điều trị cúm. Các loại thuốc Metoprolol, Atenolol và Propranolol là thuốc chống tăng huyết áp và không liên quan đến vi rút cúm.
#
# 50 -- Đáp án: A. Có
#
# ...

# %%
vi_answers[-1]
# Out:
# '.'

# %%
len(vi_answers)
# Out:
# 16324

# %%
df
# Out:
#            id                                           question  \
# 0    level3_1  Hương đang mang thai và lo lắng mình có thể gặ...
# 1    level3_2  Hương đang mang thai tuần thứ 5 và lo lắng mìn...
# 2    level3_5  Có bao nhiêu loại rau tiền đạo biết rằng trong...
# 3   level3_13  Bệnh nhân Dũng được chuẩn đoán bị viêm gan kéo...
# 4   level3_14  Một bệnh nhân bị đau tinh hoàn. Sau khi được h...
# ..        ...                                                ...
# 95   level4_4  Tiểu Đường là nữ ca sĩ nổi tiếng ở Trung Quốc....
# 96   level4_9  Mai hiện mang thai tháng thứ 9. Có rất nhiều b...
# 97  level4_27  Ông Biền năm nay 73 tuổi. Trong một bữa cơm gi...
# 98  level4_28  U não là tình trạng các khối u hình thành tron...
# 99  level4_35  Vắc xin là chế phẩm có tính kháng nguyên có ng...
#
#                           option_1             option_2  \
# 0                       A. Tuần 10            B.Tuần 20
# 1                        A. 5 tuần           B. 15 tuần
# ...

# %%
row = df.iloc[0]

# %%
choices = len(
        [
            op for op in row[["option_1", "option_2", "option_3", "option_4", "option_5", "option_6"]].tolist()
            if isinstance(op, str)
        ]
    )
choices
# Out:
# 4

# %%
results = []
for index, row in df.iterrows():
    choices = len(
        [
            op for op in row[["option_1", "option_2", "option_3", "option_4", "option_5", "option_6"]].tolist()
            if isinstance(op, str)
        ]
    )
    choices = ['0']*choices
    results.append(''.join(choices))

# %%
df['answer'] = results

# %%
new_df = df[["id", "answer"]]

# %%
new_df
# Out:
#            id answer
# 0    level3_1   0000
# 1    level3_2   0000
# 2    level3_5   0000
# 3   level3_13     00
# 4   level3_14   0000
# ..        ...    ...
# 95   level4_4   0000
# 96   level4_9   0000
# 97  level4_27   0000
# 98  level4_28   0000
# 99  level4_35    000
#
# [100 rows x 2 columns]

# %%
new_df.to_csv('./data/result_vi.csv', index=False)

# %%
row = df

# %%
context = row["context"].split("///")[0]
question = row["question"]
choices = "\n".join(
    [
        op for op in row[["option_1", "option_2", "option_3", "option_4", "option_5", "option_6"]].tolist()
        if isinstance(op, str)
    ]
)
prompt = f"Ngữ cảnh: {context}. Câu hỏi {question}. Chọn các đáp án đúng trong các đáp án sau đây: {choices}"

# %% [markdown]
# ##**BioMedLM**

# %%
# !pip install transformers accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 46.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 27.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 34.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 105.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 31.6 MB/s eta 0:00:00
# ...

# %%
row = df.iloc[1]
row
# Out:
# id                                                   level3_2
# question    Huong is 5 weeks pregnant and is worried she m...
# option_1                                           A. 5 weeks
# option_2                                          B. 15 weeks
# option_3                                          C. 25 weeks
# option_4                                          D. 35 weeks
# option_5                                                  NaN
# option_6                                                  NaN
# context     Method of diagnosing placenta praevia Usually,...
# Name: 1, dtype: object

# %%
context = row["context"].split("///")[0]
question = row["question"]
choices = "\n".join(
    [
        op for op in row[["option_1", "option_2", "option_3", "option_4", "option_5", "option_6"]].tolist()
        if isinstance(op, str)
    ]
)
prompt = f"Context: {context}. Question {question}. Choose the correct answers from the following answers: {choices}"

# %%
prompt
# Out:
# 'Context: Method of diagnosing placenta praevia Usually, the diagnosis is made by ultrasound. In addition, ultrasound is also important in diagnosing placenta previa, complications of placenta accreta. (4) Ultrasound images will show that the distance between the placenta and the bladder wall is narrowed, blood vessels passing through the uterine muscle wall to the bladder wall are common on Doppler ultrasound. Therefore, ultrasound is recommended to be performed after the 28th week of pregnancy to detect this complication early. . Question Huong is 5 weeks pregnant and is worried she may have placenta previa. How many weeks can Huong be tested to detect this disease?. Choose the correct answers from the following answers: A. 5 weeks\nB. 15 weeks\nC. 25 weeks\nD. 35 weeks'

# %%
import torch

from transformers import GPT2LMHeadModel, GPT2Tokenizer

device = torch.device("cuda")

tokenizer = GPT2Tokenizer.from_pretrained("stanford-crfm/BioMedLM")

model = GPT2LMHeadModel.from_pretrained("stanford-crfm/BioMedLM").to(device)

# %%
input_ids = tokenizer.encode(prompt, return_tensors="pt").to(device)

sample_output = model.generate(input_ids, do_sample=True, max_new_tokens=50)

tokenizer.decode(sample_output[0], skip_special_tokens=True)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:28895 for open-end generation.
# ...

# %%
from transformers import AutoTokenizer, T5ForConditionalGeneration
t5_tokenizer = AutoTokenizer.from_pretrained("luqh/ClinicalT5-large")
t5_model = T5ForConditionalGeneration.from_pretrained("luqh/ClinicalT5-large", from_flax=True)
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_flax_pytorch_utils.py:431: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   pt_model_dict[flax_key] = torch.from_numpy(flax_tensor)
# All Flax model weights were used when initializing T5ForConditionalGeneration.
#
# Some weights of T5ForConditionalGeneration were not initialized from the Flax model and are newly initialized: ['decoder.embed_tokens.weight', 'encoder.embed_tokens.weight', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
t5_model

# %%
input_ids = t5_tokenizer.encode(prompt, return_tensors="pt")

sample_output = t5_model.generate(input_ids, do_sample=True, max_new_tokens=50)

tokenizer.decode(sample_output[0], skip_special_tokens=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-a76db635dec3> in <cell line: 5>()
#       3 sample_output = t5_model.generate(input_ids, do_sample=True, max_new_tokens=50)
#       4
# ----> 5 tokenizer.decode(sample_output[0], skip_special_tokens=True)
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in decode(self, token_ids, skip_special_tokens, clean_up_tokenization_spaces, **kwargs)
#    3752         token_ids = to_py_obj(token_ids)
#    3753
# -> 3754         return self._decode(
#    3755             token_ids=token_ids,
#    3756             skip_special_tokens=skip_special_tokens,
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils.py in _decode(self, token_ids, skip_special_tokens, clean_up_tokenization_spaces, spaces_between_special_tokens, **kwargs)
# ...

# %%
t5_tokenizer.decode(sample_output[0], skip_special_tokens=True)
# Out:
# '.... #. #. #.. #.. #. #. #. #. #. #. #. #.'

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name_or_path = "m42-health/med42-70b"

model = AutoModelForCausalLM.from_pretrained(model_name_or_path,low_cpu_mem_usage=True,
                                             device_map="auto", token='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')

tokenizer = AutoTokenizer.from_pretrained(model_name_or_path)

# prompt = "What are the symptoms of diabetes ?"
# prompt_template=f'''
# <|system|>: You are a helpful medical assistant created by M42 Health in the UAE.
# <|prompter|>:{prompt}
# <|assistant|>:
# '''

# input_ids = tokenizer(prompt_template, return_tensors='pt').input_ids.cuda()
# output = model.generate(inputs=input_ids, temperature=0.7, do_sample=True,eos_token_id=tokenizer.eos_token_id, pad_token_id=tokenizer.pad_token_id, max_new_tokens=512)
# print(tokenizer.decode(output[0]))
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a35088528608> in <cell line: 5>()
#       3 model_name_or_path = "m42-health/med42-70b"
#       4
# ----> 5 model = AutoModelForCausalLM.from_pretrained(model_name_or_path,low_cpu_mem_usage=True,
#       6                                              device_map="auto", token='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')
#       7
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     563         elif type(config) in cls._model_mapping.keys():
#     564             model_class = _get_model_class(config, cls._model_mapping)
# --> 565             return model_class.from_pretrained(
#     566                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
# ...

# %%
# !pip install accelerate
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-34-ca92ad6949cc> in <cell line: 1>()
# ----> 1 get_ipython().system('pip install accelerate')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# ...

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 52.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 30.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 105.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 31.7 MB/s eta 0:00:00
# ...

# %%
# !pip install sacremoses
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895241 sha256=a517663e2dc5daefe44690075e4bb0ff7a983bed328865ceb24c68e3a751d5f5
#   Stored in directory: /root/.cache/pip/wheels/00/24/97/a2ea5324f36bc626e1ea0267f33db6aa80d157ee977e9e42fb
# Successfully built sacremoses
# ...

# %%
import torch
from transformers import BioGptTokenizer, BioGptForCausalLM, set_seed

tokenizer = BioGptTokenizer.from_pretrained("microsoft/biogpt")
model = BioGptForCausalLM.from_pretrained("microsoft/biogpt")

sentence = "COVID-19 is"
inputs = tokenizer(sentence, return_tensors="pt")

set_seed(42)

with torch.no_grad():
    beam_output = model.generate(**inputs,
                                min_length=100,
                                max_length=1024,
                                num_beams=5,
                                early_stopping=True
                                )
tokenizer.decode(beam_output[0], skip_special_tokens=True)
# Out:
# ...
# 'COVID-19 is a global pandemic caused by severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2), the causative agent of coronavirus disease 2019 (COVID-19), which has spread to more than 200 countries and territories, including the United States (US), Canada, Australia, New Zealand, the United Kingdom (UK), and the United States of America (USA), as of March 11, 2020, with more than 800,000 confirmed cases and more than 800,000 deaths.'

# %%
prompt= """Context: Method of diagnosing placenta praevia Usually, the diagnosis is made by ultrasound. In addition, ultrasound is also important in diagnosing placenta previa, complications of placenta accreta. (4) Ultrasound images will show that the distance between the placenta and the bladder wall is narrowed, blood vessels passing through the uterine muscle wall to the bladder wall are common on Doppler ultrasound. Therefore, ultrasound is recommended to be performed after the 28th week of pregnancy to detect this complication early. . Question Huong is 5 weeks pregnant and is worried she may have placenta previa. How many weeks can Huong be tested to detect this disease?. Choose the correct answers from the following answers: A. 5 weeks
B. 15 weeks
C. 25 weeks
D. 35 weeks"""

# %%
inputs = tokenizer(prompt, return_tensors="pt")

set_seed(42)

with torch.no_grad():
    beam_output = model.generate(**inputs,
                                min_length=100,
                                max_length=1024,
                                num_beams=5,
                                early_stopping=True
                                )
tokenizer.decode(beam_output[0], skip_special_tokens=True)
# Out:
# 'Context: Method of diagnosing placenta praevia Usually, the diagnosis is made by ultrasound. In addition, ultrasound is also important in diagnosing placenta previa, complications of placenta accreta. (4) Ultrasound images will show that the distance between the placenta and the bladder wall is narrowed, blood vessels passing through the uterine muscle wall to the bladder wall are common on Doppler ultrasound. Therefore, ultrasound is recommended to be performed after the 28th week of pregnancy to detect this complication early.. Question Huong is 5 weeks pregnant and is worried she may have placenta previa. How many weeks can Huong be tested to detect this disease?. Choose the correct answers from the following answers: A. 5 weeks B. 15 weeks C. 25 weeks D. 35 weeks.'
